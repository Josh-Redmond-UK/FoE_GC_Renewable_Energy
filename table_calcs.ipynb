# %%
import pandas as pd
import numpy as np

# %%
constituencies = pd.read_csv("constituencies_names.csv")
constituencies = constituencies.rename(columns = {"pcon19nm" : "Constituency"})

# %%
# Random numbers for data
data = pd.DataFrame(np.random.randint(7, 12000, size = (650, 5)), columns = ["A", "B", "C", "D", "E"])
data = data.set_index(constituencies["Constituency"])
data
data.style.format({"A": "{:20,.0f}", 
                          "B": "{:20,.0f}", 
                          "C": "{:20,.0f}",
                          "D":"{:20,.0f}",
                          "E": "{:20,.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_30026">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30026_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_30026_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_30026_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_30026_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_30026_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Constituency</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30026_level0_row0" class="row_heading level0 row0" >Aldershot</th>
#       <td id="T_30026_row0_col0" class="data row0 col0" >               8,236</td>
#       <td id="T_30026_row0_col1" class="data row0 col1" >               1,717</td>
#       <td id="T_30026_row0_col2" class="data row0 col2" >                 192</td>
#       <td id="T_30026_row0_col3" class="data row0 col3" >                 468</td>
#       <td id="T_30026_row0_col4" class="data row0 col4" >               1,442</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row1" class="row_heading level0 row1" >Aldridge-Brownhills</th>
#       <td id="T_30026_row1_col0" class="data row1 col0" >               8,643</td>
#       <td id="T_30026_row1_col1" class="data row1 col1" >               1,725</td>
#       <td id="T_30026_row1_col2" class="data row1 col2" >              11,437</td>
#       <td id="T_30026_row1_col3" class="data row1 col3" >               8,695</td>
#       <td id="T_30026_row1_col4" class="data row1 col4" >               6,859</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row2" class="row_heading level0 row2" >Altrincham and Sale West</th>
#       <td id="T_30026_row2_col0" class="data row2 col0" >               9,611</td>
#       <td id="T_30026_row2_col1" class="data row2 col1" >               3,290</td>
#       <td id="T_30026_row2_col2" class="data row2 col2" >               3,750</td>
#       <td id="T_30026_row2_col3" class="data row2 col3" >               1,728</td>
#       <td id="T_30026_row2_col4" class="data row2 col4" >               2,589</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row3" class="row_heading level0 row3" >Amber Valley</th>
#       <td id="T_30026_row3_col0" class="data row3 col0" >               5,785</td>
#       <td id="T_30026_row3_col1" class="data row3 col1" >               7,163</td>
#       <td id="T_30026_row3_col2" class="data row3 col2" >               8,410</td>
#       <td id="T_30026_row3_col3" class="data row3 col3" >               4,063</td>
#       <td id="T_30026_row3_col4" class="data row3 col4" >               9,672</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row4" class="row_heading level0 row4" >Arundel and South Downs</th>
#       <td id="T_30026_row4_col0" class="data row4 col0" >               2,378</td>
#       <td id="T_30026_row4_col1" class="data row4 col1" >               5,187</td>
#       <td id="T_30026_row4_col2" class="data row4 col2" >               7,844</td>
#       <td id="T_30026_row4_col3" class="data row4 col3" >               3,003</td>
#       <td id="T_30026_row4_col4" class="data row4 col4" >               1,669</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row5" class="row_heading level0 row5" >Ashfield</th>
#       <td id="T_30026_row5_col0" class="data row5 col0" >               9,151</td>
#       <td id="T_30026_row5_col1" class="data row5 col1" >               4,456</td>
#       <td id="T_30026_row5_col2" class="data row5 col2" >              10,615</td>
#       <td id="T_30026_row5_col3" class="data row5 col3" >              11,334</td>
#       <td id="T_30026_row5_col4" class="data row5 col4" >               1,827</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row6" class="row_heading level0 row6" >Ashford</th>
#       <td id="T_30026_row6_col0" class="data row6 col0" >               1,574</td>
#       <td id="T_30026_row6_col1" class="data row6 col1" >               8,101</td>
#       <td id="T_30026_row6_col2" class="data row6 col2" >               6,881</td>
#       <td id="T_30026_row6_col3" class="data row6 col3" >               1,469</td>
#       <td id="T_30026_row6_col4" class="data row6 col4" >               3,696</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row7" class="row_heading level0 row7" >Ashton-under-Lyne</th>
#       <td id="T_30026_row7_col0" class="data row7 col0" >               6,260</td>
#       <td id="T_30026_row7_col1" class="data row7 col1" >               9,957</td>
#       <td id="T_30026_row7_col2" class="data row7 col2" >               8,105</td>
#       <td id="T_30026_row7_col3" class="data row7 col3" >               3,960</td>
#       <td id="T_30026_row7_col4" class="data row7 col4" >               2,167</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row8" class="row_heading level0 row8" >Aylesbury</th>
#       <td id="T_30026_row8_col0" class="data row8 col0" >               8,203</td>
#       <td id="T_30026_row8_col1" class="data row8 col1" >               3,210</td>
#       <td id="T_30026_row8_col2" class="data row8 col2" >                 763</td>
#       <td id="T_30026_row8_col3" class="data row8 col3" >               4,687</td>
#       <td id="T_30026_row8_col4" class="data row8 col4" >               4,983</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row9" class="row_heading level0 row9" >Banbury</th>
#       <td id="T_30026_row9_col0" class="data row9 col0" >               5,362</td>
#       <td id="T_30026_row9_col1" class="data row9 col1" >               1,924</td>
#       <td id="T_30026_row9_col2" class="data row9 col2" >               5,360</td>
#       <td id="T_30026_row9_col3" class="data row9 col3" >               4,209</td>
#       <td id="T_30026_row9_col4" class="data row9 col4" >               7,178</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row10" class="row_heading level0 row10" >Barking</th>
#       <td id="T_30026_row10_col0" class="data row10 col0" >              10,676</td>
#       <td id="T_30026_row10_col1" class="data row10 col1" >               6,549</td>
#       <td id="T_30026_row10_col2" class="data row10 col2" >               2,715</td>
#       <td id="T_30026_row10_col3" class="data row10 col3" >               6,963</td>
#       <td id="T_30026_row10_col4" class="data row10 col4" >              11,149</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row11" class="row_heading level0 row11" >Barnsley Central</th>
#       <td id="T_30026_row11_col0" class="data row11 col0" >               8,456</td>
#       <td id="T_30026_row11_col1" class="data row11 col1" >              11,098</td>
#       <td id="T_30026_row11_col2" class="data row11 col2" >               7,741</td>
#       <td id="T_30026_row11_col3" class="data row11 col3" >               7,887</td>
#       <td id="T_30026_row11_col4" class="data row11 col4" >               7,153</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row12" class="row_heading level0 row12" >Barnsley East</th>
#       <td id="T_30026_row12_col0" class="data row12 col0" >               2,986</td>
#       <td id="T_30026_row12_col1" class="data row12 col1" >               7,422</td>
#       <td id="T_30026_row12_col2" class="data row12 col2" >               5,425</td>
#       <td id="T_30026_row12_col3" class="data row12 col3" >               2,607</td>
#       <td id="T_30026_row12_col4" class="data row12 col4" >               3,053</td>
#     </tr>
#     <tr>
#       <th id="T_30026_level0_row13" class="row_heading level0 row13" >Barrow and Furness</th>
#       <td id="T_30026_row13_col0" class="data row13 col0" >               5,591</td>
#       <td id="T_30026_row13_col1" class="data row13 col1" >              10,140</td>
#       <td id="T_30026_row13_col2" class="data row13 col2" >               2,718</td>
#       <td id="T_30026_ro

# %%
data = pd.DataFrame(np.random.randint(7, 12000, size = (650, 4)), columns = ["Available wind area (sq.km)", "Expected wind output (MW)", "Available solar area (sq. km)", "Expected solar output (MW)"])
data = data.set_index(constituencies["Constituency"])
data = data.rename_axis("Constituency")

# # Output dataframe
# st.dataframe(data = data.style.format({"Available wind area (sq.km)": "{:20,.0f}", 
#                           "Expected wind output (MW)": "{:20,.0f}", 
#                           "Available solar area (sq. km)": "{:20,.0f}",
#                           "Expected solar output (MW)":"{:20,.0f}"}), width = 1000, height = 750)


# Calculate total potential
potentials = pd.DataFrame()
data["Expected wind output (MW)"].sum()
potentials["Test"] = [data["Expected solar output (MW)"].sum()]
potentials
# Out:
#       Test
# 0  3855932

# %%
total_output = data["A"].sum()
total_output
# Out:
# 3965981

# %%
# # Calculate available area

# # Calculate expected output: full resources, wind
# full_output_wind = []
# for i in range(len(data)):
#     full_output_wind.append(i * 19.8)

# # Calculate expected output: limited resources, wind
# limited_output_wind = []
# for i in range(len(data)):
#     limited_output_wind.append(i * 5)

# # Calculate expected output: full resources, solar
# full_output_solar = []
# for i in range(len(data)):
#     full_output_solar.append(i * 200)
# # Calculate expected output: limited resources, solar
# limited_output_solar = []
# for i in range(len(data)):
#     full_output_solar.append(i * 50)
# # Calculate total energy potential
